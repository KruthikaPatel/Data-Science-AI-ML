# %%
import cv2
import matplotlib.pyplot as plt

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in e:\anakonda\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in e:\anakonda\lib\site-packages (from opencv-python) (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
img=cv2.imread(r"C:\Users\Lenovo\OneDrive\Pictures\paris.jpg" )

# %%
img
# Out:
# array([[[221, 177, 154],
#         [222, 175, 153],
#         [224, 175, 153],
#         ...,
#         [217, 175, 170],
#         [215, 173, 168],
#         [213, 174, 166]],
#
#        [[220, 176, 153],
#         [222, 175, 153],
#         [224, 175, 153],
#         ...,
#         [216, 174, 169],
#         [215, 173, 168],
#         [213, 174, 166]],
#
#        [[220, 176, 153],
#         [222, 175, 153],
#         [222, 175, 153],
#         ...,
#         [216, 174, 169],
#         [216, 174, 169],
#         [215, 173, 166]],
#
#        ...,
#
#        [[ 26,   9,  18],
#         [ 28,  12,  19],
#         [ 26,  10,  17],
#         ...,
#         [ 41,  27,  31],
#         [ 41,  27,  31],
#         [ 47,  33,  37]],
#
#        [[ 24,   8,  15],
#         [ 27,  11,  18],
#         [ 25,  10,  14],
#         ...,
#         [ 50,  39,  42],
#         [ 43,  29,  33],
#         [ 45,  31,  35]],
#
#        [[ 26,  11,  15],
#         [ 22,   7,  11],
#         [ 24,  10,  12],
#         ...,
#         [ 46,  32,  38],
#         [ 45,  31,  37],
#         [ 51,  36,  40]]], shape=(1001, 640, 3), dtype=uint8)

# %%
img.shape
# Out:
# (1001, 640, 3)

# %%
plt.imshow(img)
plt. axis("off")
plt.show()

# %%
plt.imshow(img, cmap='gray')
plt. axis("off")
plt.show()

# %%
#image reshaping
img.shape
# Out:
# (1001, 640, 3)

# %%
resized_img=cv2.resize(img,(100,100))
plt.imshow(resized_img)
plt.show()

# %%
resized_img=cv2.resize(img,(100,100))
plt.imshow(img)
plt.show()

# %%
plt.imshow(img[200:800 ,200:600])

# %%
 #Image Color Conversion
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
hsv=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

# %%
plt.imshow(gray, cmap='gray')
plt.title("Grayscale")
plt.show()

# %%
##Rotate 
h,w=img.shape[:2]
center=(h//2, w//2)
matrix=cv2.getRotationMatrix2D(center, 50,0.6)
rotated=cv2.warpAffine(img,matrix,(w,h))
plt.imshow(rotated)

# %%
# SEGMENTATION
# THRESHOLD VALUES
val, thres=cv2.threshold(gray, 180, 255,cv2.THRESH_BINARY)

# %%
val
# Out:
# 180.0

# %%
plt.imshow(thres, cmap="gray")
