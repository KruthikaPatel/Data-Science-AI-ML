# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Lenovo\Downloads\car_price_prediction.csv")

# %%
df
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
# ...

# %%
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
df.shape
# Out:
# (19237, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
# ...

# %%
df.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
df["Levy"] = df["Levy"].replace("-", None)
df["Levy"] = pd.to_numeric(df["Levy"])
df.isnull().sum()
# Out:
# ID                     0
# Price                  0
# Levy                5819
# Manufacturer           0
# Model                  0
# Prod. year             0
# Category               0
# Leather interior       0
# Fuel type              0
# Engine volume          0
# Mileage                0
# Cylinders              0
# Gear box type          0
# Drive wheels           0
# Doors                  0
# Wheel                  0
# Color                  0
# Airbags                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 313

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18924 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18924 non-null  int64
#  1   Price             18924 non-null  int64
#  2   Levy              13215 non-null  float64
#  3   Manufacturer      18924 non-null  int32
#  4   Model             18924 non-null  int32
#  5   Prod. year        18924 non-null  int64
#  6   Category          18924 non-null  int32
#  7   Leather interior  18924 non-null  int32
#  8   Fuel type         18924 non-null  int32
#  9   Engine volume     18924 non-null  int32
#  10  Mileage           18924 non-null  int32
#  11  Cylinders         18924 non-null  float64
#  12  Gear box type     18924 non-null  int32
#  13  Drive wheels      18924 non-null  int32
#  14  Doors             18924 non-null  int32
#  15  Wheel             18924 non-null  int32
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["Price"])
plt.title("Car Price Distribution")
plt.show()

# %%
skewness = df["Price"].skew()

# %%
print("Skewness of Price:", skewness)
# Out:
# Skewness of Price: 135.38772637953886

# %%
df = df.copy()  # prevents SettingWithCopyWarning

# %%
df['Price_pos'] = df['Price'] + 1

# %%
from scipy.stats import boxcox

# Automatically finds lambda to reduce skewness
df['Price_boxcox'], lambda_value = boxcox(df['Price_pos'])

print("Lambda used:", lambda_value)
print("Skewness after Box-Cox:", df['Price_boxcox'].skew())
# Out:
# Lambda used: 0.9963286254101655
# Skewness after Box-Cox: 0.2806083947477075

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['Price'])
plt.show()

# %%
import pandas as pd

# Make sure you are working on a copy of the DataFrame to avoid warnings
df = df.copy()

# Step 1: Calculate Q1, Q3, and IQR
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1

# Step 2: Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Remove outliers
df_no_outliers = df[(df['Price'] >= lower_bound) & (df['Price'] <= upper_bound)]

print("Original dataset size:", df.shape)
print("Dataset size after removing outliers:", df_no_outliers.shape)

# Step 4: Visualize to confirm
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df_no_outliers['Price'])
plt.title("Price Boxplot with No Outliers")
plt.show()
# Out:
# Original dataset size: (18924, 21)
# Dataset size after removing outliers: (18531, 21)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['Price'])
plt.show()

# %%
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print("Lower:", lower)
print("Upper:", upper)
# Out:
# Lower: 7.183117387077811
# Upper: 81.86798529792092

# %%
df= df[(df['Price'] >= lower) & (df['Price'] <= upper)]

# %%
sns.boxplot(x=df['Price'])
plt.show()

# %%
((df['Price'] < lower) | (df['Price'] > upper)).sum()
# Out:
# 0

# %%
print(df['Price'].min())
print(df['Price'].max())
# Out:
# 7.33695071718067
# 81.8250600256206

# %%
df.shape
# Out:
# (18531, 21)

# %%
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags', 'Price_log', 'Price_pos', 'Price_boxcox'],
#       dtype='object')
